# %%
#https://medium.com/@samlupton/spotipy-get-features-from-your-favourite-songs-in-python-6d71f0172df0

#spotipy has a wealth of other functionality, including getting all songs from a playlist or extracting the popularity of a track, so do explore away!

# %%
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
from tqdm import tqdm_notebook
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '8e6e962237b74490aca58fd858c5a54f'
client_secret = '06fd25cc7b164f7e88927938c5c1a589'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

def playlist_tracks(genre):
    
    '''
    Takes a list of genre names, iterates through their Spotify playlists, checks for 
    duplicate albums, then appends all the tracks in those playlists to a list of lists
    '''
    
    # Each list in this list will be a track and its features
    tracks = []
    
    
    
    for genre in tqdm_notebook(genres):
        
        # Get the playlist URI (a unique ID)
        playlist_uri = sp.search(genre)#['tracks']['items'][0]['playlists'][0]['uri']

        # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
        #album_checker = []
        
        # The starting point of our loop of albums for those artists with more than 50
        #n = 0
        
        # Note the album_type = 'album'. This discounts singles, compilations and collaborations
        #while len(sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']) > 0:
            
            # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
            #dict_list = sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']
            
            #for i, album in tqdm_notebook(enumerate(dict_list)):

                # Add the featured artists for the album in question to the checklist
                #check_this_album = [j['name'] for j in dict_list[i]['artists']]
                # And the album name
                #check_this_album.append(dict_list[i]['name'])
                # And its date
                #check_this_album.append(dict_list[i]['release_date'])

                # Only continue looping if that album isn't in the checklist
                #if check_this_album not in album_checker:
                    
                    # Add this album to the checker
                    #album_checker.append(check_this_album)
                    # For every song on the album, get its descriptors and features in a list and add to the tracklist
                    #tracks.extend([[playlist, playlist['name'], playlist['uri'], song['name'],

                      #song['release_date']] + list(sp.audio_features(song['uri'])[0].values()) 
                                   #for song in sp.playlist_tracks(playlist['uri'])['items']])
            
            # Go through the next 50 albums (otherwise we'll get an infinite while loop)
            #n += 50

    return playlist_uri

# %%
playlist_tracks(['dance'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-06a2da6ff9ed> in <module>
# ----> 1 playlist_tracks(['dance'])
#
# <ipython-input-1-7c33699d5124> in playlist_tracks(genre)
#      21
#      22
# ---> 23     for genre in tqdm_notebook(genres):
#      24
#      25         # Get the playlist URI (a unique ID)
#
# NameError: name 'genres' is not defined

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = '8e6e962237b74490aca58fd858c5a54f'
client_secret = '06fd25cc7b164f7e88927938c5c1a589'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

def df_tracks(tracklist):
    
    '''
    Takes the output of artist_tracks (i.e. a list of lists),
    puts it in a dataframe and formats it.
    '''

    df = pd.DataFrame(tracklist, columns=['artist',
     'album_name',
     'album_uri',
     'track',
     'release_date'] + list(sp.audio_features('7tr2za8SQg2CI8EDgrdtNl')[0].keys()))

    df.rename(columns={'uri':'song_uri'}, inplace=True)

    df.drop_duplicates(subset=['artist', 'track', 'release_date'], inplace=True)

    # Reorder the cols to have identifiers first, auditory features last
    cols = ['artist', 'album_name', 'album_uri', 'track', 'release_date', 'id', 'song_uri', 'track_href',
     'analysis_url', 'type', 'danceability', 'energy', 'key',  'loudness', 'mode', 'speechiness',
     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']

    df = df[cols]
    
    return df

# %%
tracklist = artist_tracks(['Masego'])
# Out:
# <ipython-input-1-eface1997f7e>:23: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for artist in tqdm_notebook(artists):
#   0%|          | 0/1 [00:00<?, ?it/s]
# <ipython-input-1-eface1997f7e>:40: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, album in tqdm_notebook(enumerate(dict_list)):
# 0it [00:00, ?it/s]

# %%
df_tracks(tracklist)
# Out:
#     artist                      album_name  \
# 0   Masego  Studying Abroad: Extended Stay
# 1   Masego  Studying Abroad: Extended Stay
# 2   Masego  Studying Abroad: Extended Stay
# 3   Masego  Studying Abroad: Extended Stay
# 4   Masego  Studying Abroad: Extended Stay
# 5   Masego  Studying Abroad: Extended Stay
# 6   Masego  Studying Abroad: Extended Stay
# 7   Masego  Studying Abroad: Extended Stay
# 8   Masego  Studying Abroad: Extended Stay
# 9   Masego  Studying Abroad: Extended Stay
# 10  Masego  Studying Abroad: Extended Stay
# 11  Masego                       Lady Lady
# 12  Masego                       Lady Lady
# 13  Masego                       Lady Lady
# 14  Masego                       Lady Lady
# 15  Masego                       Lady Lady
# 16  Masego                       Lady Lady
# 17  Masego                       Lady Lady
# 18  Masego                       Lady Lady
# 19  Masego                       Lady Lady
# 20  Masego                       Lady Lady
# 21  Masego                       Lady Lady
# 22  Masego                       Lady Lady
# 23  Masego                       Lady Lady
# 24  Masego                       Lady Lady
# 25  Masego                  Loose Thoughts
# 26  Masego                  Loose Thoughts
# 27  Masego                  Loose Thoughts
# 28  Masego                  Loose Thoughts
# 29  Masego                  Loose Thoughts
# 30  Masego                  Loose Thoughts
# 31  Masego                  Loose Thoughts
# 32  Masego                  Loose Thoughts
# 33  Masego                  Loose Thoughts
#
#                                album_uri  \
# 0   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 1   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 2   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 3   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 4   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 5   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 6   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 7   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 8   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 9   spotify:album:1S0yIZRDiFmqCQyTIEV175
# 10  spotify:album:1S0yIZRDiFmqCQyTIEV175
# 11  spotify:album:2wqG59dVVQlJaxoO7N0LJt
# 12  spotify:album:2wqG59dVVQlJaxoO7N0LJt
# 13  spotify:album:2wqG59dVVQlJaxoO7N0LJt
# 29  1U0yNemUKpAtdMwrUGL1EV  spotify:track:1U0yNemUKpAtdMwrUGL1EV
# 30  26saXCJygpu82pgiigi4K3  spotify:track:26saXCJygpu82pgiigi4K3
# 31  3hh7o609txYZUs8K6Kpeca  spotify:track:3hh7o609txYZUs8K6Kpeca
# 32  7jilSPtwxle48tSOOhzAa5  spotify:track:7jilSPtwxle48tSOOhzAa5
# 33  2LgEYzVoSKp6fsST6trUh2  spotify:track:2LgEYzVoSKp6fsST6trUh2
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/24aKIsuJixaS...
# 1   https://api.spotify.com/v1/tracks/6Ap0yGl178iQ...
# 2   https://api.spotify.com/v1/tracks/0bkTdkWwGk3O...
# 3   https://api.spotify.com/v1/tracks/3BV5JdSgfZUb...
# 4   https://api.spotify.com/v1/tracks/1Hl52AxTWYv4...
# 5   https://api.spotify.com/v1/tracks/0A8ubu9Rgt5a...
# 6   https://api.spotify.com/v1/tracks/7bnhPW64dgFL...
# 7   https://api.spotify.com/v1/tracks/6ewrGkoQWQvt...
# 8   https://api.spotify.com/v1/tracks/6eJhXvPmlzy5...
# 9   https://api.spotify.com/v1/tracks/0ed7g01Suk6I...
# 10  https://api.spotify.com/v1/tracks/4mw6T97oRssa...
# 11  https://api.spotify.com/v1/tracks/6rQdSzIFkrSP...
# 12  https://api.spotify.com/v1/tracks/1wBK3EFlicez...
# 13  https://api.spotify.com/v1/tracks/4dulFGnSzdNW...
# 14  https://api.spotify.com/v1/tracks/1gWL7x24c5s7...
# 15  https://api.spotify.com/v1/tracks/5KaIIT6ijzJv...
# 16  https://api.spotify.com/v1/tracks/10QawadmmX0J...
# 17  https://api.spotify.com/v1/tracks/5tkR9JkBj3Ue...
# 18  https://api.spotify.com/v1/tracks/4bHjtWXjI8DT...
# 19  https://api.spotify.com/v1/tracks/0XX5J55td3eE...
# 20  https://api.spotify.com/v1/tracks/4q4kOEBru4Pw...
# 21  https://api.spotify.com/v1/tracks/10PZ423Ycq6w...
# 22  https://api.spotify.com/v1/tracks/08WHknhqizAD...
# 23  https://api.spotify.com/v1/tracks/51rPRW8NjxZo...
# 24  https://api.spotify.com/v1/tracks/2XSV2XlfV0DQ...
# 25  https://api.spotify.com/v1/tracks/7L8I5H4YJpBq...
# 26  https://api.spotify.com/v1/tracks/4nXhb6Qu01B7...
# 27  https://api.spotify.com/v1/tracks/2gp3Wb5SQeEK...
# 28  https://api.spotify.com/v1/tracks/6MuDC6T5q2uy...
# 29  https://api.spotify.com/v1/tracks/1U0yNemUKpAt...
# 30  https://api.spotify.com/v1/tracks/26saXCJygpu8...
# 31  https://api.spotify.com/v1/tracks/3hh7o609txYZ...
# 32  https://api.spotify.com/v1/tracks/7jilSPtwxle4...
# 33  https://api.spotify.com/v1/tracks/2LgEYzVoSKp6...
#
#                                          analysis_url            type  ...  \
# 0   https://api.spotify.com/v1/audio-analysis/24aK...  audio_features  ...
# 1   https://api.spotify.com/v1/audio-analysis/6Ap0...  audio_features  ...
# 2   https://api.spotify.com/v1/audio-analysis/0bkT...  audio_features  ...
# 3   https://api.spotify.com/v1/audio-analysis/3BV5...  audio_features  ...
# 4   https://api.spotify.com/v1/audio-analysis/1Hl5...  audio_features  ...
# 5   https://api.spotify.com/v1/audio-analysis/0A8u...  audio_features  ...
# 6   https://api.spotify.com/v1/audio-analysis/7bnh...  audio_features  ...
# 7   https://api.spotify.com/v1/audio-analysis/6ewr...  audio_features  ...
# 8   https://api.spotify.com/v1/audio-analysis/6eJh...  audio_features  ...
# 9   https://api.spotify.com/v1/audio-analysis/0ed7...  audio_features  ...
# 10  https://api.spotify.com/v1/audio-analysis/4mw6...  audio_features  ...
# 11  https://api.spotify.com/v1/audio-analysis/6rQd...  audio_features  ...
# 12  https://api.spotify.com/v1/audio-analysis/1wBK...  audio_features  ...
# 13  https://api.spotify.com/v1/audio-analysis/4dul...  audio_features  ...
# 14  https://api.spotify.com/v1/audio-analysis/1gWL...  audio_features  ...
# 15  https://api.spotify.com/v1/audio-analysis/5KaI...  audio_features  ...
# 16  https://api.spotify.com/v1/audio-analysis/10Qa...  audio_features  ...
# 17  https://api.spotify.com/v1/audio-analysis/5tkR...  audio_features  ...
# 18  https://api.spotify.com/v1/audio-analysis/4bHj...  audio_features  ...
# 19  https://api.spotify.com/v1/audio-analysis/0XX5...  audio_features  ...
# 20  https://api.spotify.com/v1/audio-analysis/4q4k...  audio_features  ...
# 21  https://api.spotify.com/v1/audio-analysis/10PZ...  audio_features  ...
# 22  https://api.spotify.com/v1/audio-analysis/08WH...  audio_features  ...
# 23  https://api.spotify.com/v1/audio-analysis/51rP...  audio_features  ...
# 24  https://api.spotify.com/v1/audio-analysis/2XSV...  audio_features  ...
# 25  https://api.spotify.com/v1/audio-analysis/7L8I...  audio_features  ...
# 26  https://api.spotify.com/v1/audio-analysis/4nXh...  audio_features  ...
# 27  https://api.spotify.com/v1/audio-analysis/2gp3...  audio_features  ...
# 28  https://api.spotify.com/v1/audio-analysis/6MuD...  audio_features  ...
# 29  https://api.spotify.com/v1/audio-analysis/1U0y...  audio_features  ...
# 30  https://api.spotify.com/v1/audio-analysis/26sa...  audio_features  ...
# 31  https://api.spotify.com/v1/audio-analysis/3hh7...  audio_features  ...
# 32  https://api.spotify.com/v1/audio-analysis/7jil...  audio_features  ...
# 33  https://api.spotify.com/v1/audio-analysis/2LgE...  audio_features  ...
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    -12.042     1       0.2140        0.7300          0.000000    0.2900
# 1     -8.492     0       0.0735        0.4690          0.000222    0.2060
# 2     -7.957     0       0.1410        0.3930          0.000000    0.0982
# 3     -9.878     0       0.0542        0.8380          0.030600    0.2430
# 4    -11.119     0       0.1540        0.2410          0.000009    0.1010
# 5     -9.842     0       0.0584        0.6810          0.065300    0.2590
# 6     -9.633     0       0.0513        0.7440          0.000000    0.2540
