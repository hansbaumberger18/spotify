# %% [markdown]
# # EDA
#
# In this notebook metadata of songs in the dataset created will be explored for insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/DATA.csv')

print(df.shape)
df.head()
# Out:
# (31023, 17)
#                        id                           title  \
# 0  2ROJOb98GorxStuOuZWcGd    Have You Ever Loved A Woman?
# 1  2Qj1FilGsXITZbFVmVeoLy                   I'm Tore Down
# 2  2FtX5tOFUVOyjcGQiuGR8f  Damn Right, I've Got the Blues
# 3  6f3OYG5R630tjwFIHIE7j2                 Scratch My Back
# 4  4VCl2a5JvdrEx6PL2P29ty              The Thrill Is Gone
#
#                  all_artists  popularity release_date  danceability  energy  \
# 0        Derek & The Dominos          61   1970-11-01         0.303   0.648
# 1               Freddie King          57         1971         0.640   0.496
# 2                  Buddy Guy          57         1991         0.353   0.921
# 3  The Fabulous Thunderbirds          56         1979         0.775   0.499
# 4                  B.B. King           0   2014-12-08         0.554   0.516
#
#    key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0    0    -6.795     1        0.6420          0.053000    0.4070    0.644
# 1    2   -11.124     1        0.6160          0.000046    0.1830    0.954
# 2    2    -5.640     1        0.0488          0.065000    0.3140    0.526
# 3    4    -7.181     1        0.4960          0.021900    0.1140    0.862
# 4    9    -6.819     0        0.2240          0.286000    0.0548    0.562
#
#      tempo  duration_ms  time_signature
# 0  170.379       412960               3
# 1  116.632       253333               4
# 2  145.589       271653               3
# 3  121.056       232707               4
# 4   90.309       324267               4

# %%
# Check for null values
pd.isnull(df).sum()
# Out:
# id                  0
# title               3
# all_artists         3
# popularity          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
# Drop rows containing null values as they aren't a significant number
df.dropna(inplace = True)
df.shape
# Out:
# (31020, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31020 entries, 0 to 31022
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                31020 non-null  object
#  1   title             31020 non-null  object
#  2   all_artists       31020 non-null  object
#  3   popularity        31020 non-null  int64
#  4   release_date      31020 non-null  object
#  5   danceability      31020 non-null  float64
#  6   energy            31020 non-null  float64
#  7   key               31020 non-null  int64
#  8   loudness          31020 non-null  float64
#  9   mode              31020 non-null  int64
#  10  acousticness      31020 non-null  float64
#  11  instrumentalness  31020 non-null  float64
#  12  liveness          31020 non-null  float64
#  13  valence           31020 non-null  float64
#  14  tempo             31020 non-null  float64
#  15  duration_ms       31020 non-null  int64
#  16  time_signature    31020 non-null  int64
# dtypes: float64(8), int64(5), object(4)
# memory usage: 4.3+ MB

# %%
#Dropping duplicate songs
df.drop_duplicates(['id'], inplace = True)
df.shape
# Out:
# (27859, 17)

# %%
#A bit of feature engineering...

#change release_date to release_year
df['release_year'] = df['release_date'].apply(lambda x: x.split('-')[0])
df.drop(columns = ['release_date'], inplace = True)
    
#Change duration in miliseconds to seconds and drop duration_ms column
df['duration'] = df['duration_ms'].apply(lambda x: round(x/1000))
df.drop(columns = ['duration_ms'], inplace = True)
df.head(1)
# Out:
#                        id                         title          all_artists  \
# 0  2ROJOb98GorxStuOuZWcGd  Have You Ever Loved A Woman?  Derek & The Dominos
#
#    popularity  danceability  energy  key  loudness  mode  acousticness  \
# 0          61         0.303   0.648    0    -6.795     1         0.642
#
#    instrumentalness  liveness  valence    tempo  time_signature release_year  \
# 0             0.053     0.407    0.644  170.379               3         1970
#
#    duration
# 0       413

# %%
#Statistical scores
df.describe().transpose()
# Out:
#                     count        mean        std       min       25%  \
# popularity        27859.0   39.724577  25.118889   0.00000   21.0000
# danceability      27859.0    0.591953   0.165591   0.00000    0.4880
# energy            27859.0    0.664853   0.234083   0.00002    0.5320
# key               27859.0    5.328942   3.569749   0.00000    2.0000
# loudness          27859.0   -8.004376   4.953295 -47.07000   -9.5075
# mode              27859.0    0.643921   0.478847   0.00000    0.0000
# acousticness      27859.0    0.241546   0.301649   0.00000    0.0123
# instrumentalness  27859.0    0.117908   0.269736   0.00000    0.0000
# liveness          27859.0    0.186919   0.150959   0.01200    0.0928
# valence           27859.0    0.537440   0.250574   0.00000    0.3440
# tempo             27859.0  121.258621  28.144055   0.00000   99.9640
# time_signature    27859.0    3.937435   0.324417   0.00000    4.0000
# duration          27859.0  232.159984  76.802445  30.00000  188.0000
#
#                          50%       75%       max
# popularity         44.000000   59.0000   100.000
# danceability        0.605000    0.7120     0.988
# energy              0.715000    0.8500     0.999
# key                 5.000000    9.0000    11.000
# loudness           -6.651000   -4.8970     4.140
# mode                1.000000    1.0000     1.000
# acousticness        0.092300    0.3860     0.996
# instrumentalness    0.000064    0.0159     0.997
# liveness            0.126000    0.2420     0.987
# valence             0.546000    0.7410     0.993
# tempo             120.057000  137.8340   230.008
# time_signature      4.000000    4.0000     5.000
# duration          219.000000  258.0000  1412.000

# %%
# Boxplot to display the above grid
sns.set(rc = {'figure.figsize':(15,8)})
sns.boxplot(data=df[['danceability', 'energy', 'acousticness', 'instrumentalness',
       'liveness', 'valence']]).set(title= 'Feature boxplots')
plt.xlabel('Features')
plt.ylabel('Value')
plt.show()

# %%
# Show artist by popularity
artist_by_pop = df.groupby('all_artists').sum().sort_values('popularity', ascending = False)[:10]
artist_by_pop
# Out:
#                    popularity  danceability   energy  key  loudness  mode  \
# all_artists
# Arctic Monkeys           5610        52.648  88.2250  642  -693.576    60
# Taylor Swift             4254        37.230  39.0510  318  -392.969    51
# Twenty One Pilots        2493        26.832  27.8901  224  -254.379    23
# Drake                    2311        26.726  21.8740  193  -227.425    19
# The Strokes              2221        25.911  36.8570  228  -279.012    39
# Coldplay                 2203        16.629  21.7650  209  -246.449    22
# Kanye West               2159        28.733  30.0700  182  -261.722    24
# Rihanna                  2099        27.823  30.1970  288  -213.096    17
# Bruno Mars               2014        20.643  20.1440  125  -154.029    19
# Maluma                   1973        25.424  25.7650  186  -137.023    16
#
#                    acousticness  instrumentalness  liveness  valence  \
# all_artists
# Arctic Monkeys         7.980844          7.062638   20.2815  64.0925
# Taylor Swift          11.764118          0.036907    8.5744  28.8292
# Twenty One Pilots      5.165138          0.391549    6.6220  21.9670
# Drake                  4.680710          0.086586    6.0212  15.5004
# The Strokes            4.452308         16.904675    8.3933  28.9440
# Coldplay               5.654345          2.009529    5.5294   9.9815
# Kanye West             6.834808          0.500965   12.8365  18.6358
# Rihanna                3.138085          0.436430    7.3685  23.7950
# Bruno Mars             6.185680          0.000244    5.1593  18.5834
# Maluma                 6.594900          0.002469    5.3380  22.5330
#
#                        tempo  time_signature  duration
# all_artists
# Arctic Monkeys     14221.163             451     22594
# Taylor Swift        7106.185             243     15035
# Twenty One Pilots   4965.878             163      9354
# Drake               4327.370             144      8243
# The Strokes         6179.638             197     10624
# Coldplay            4428.057             136      9029
# Kanye West          5900.635             184     10906
# Rihanna             5070.023             163      9758
# Bruno Mars          3514.803             116      6375
# Maluma              3981.987             131      6776

# %%
# 10 least popular songs in the dataset
least_popular = df.sort_values('popularity', ascending = True)
least_popular.head(10)
# Out:
#                            id  \
# 15534  0DNk7lEqDGCN6nDD0H8emF
# 15761  4HE4lZRuRhIU07dcSzxWQR
# 15762  1eEf377CT72VUE8RFiTcZ9
# 5823   6nF4Jorqzz1mWdhMfIKjJC
# 5822   4IyWdJvm6qsWlYG0oKzlbY
# 5821   3cdAH0xKu7t3uPoFTHAlsN
# 5820   66wpCqkkM6MrxXSbfgmsrh
# 15763  3ZgA55mdHPByN2SrrikKJu
# 5814   3F6mZ61oIQJobfg2qRPK4j
# 5813   7ro41pqd6RjNe03XEhb6q0
#
#                                                    title  \
# 15534                                     September Song
# 15761                                      The Down Town
# 15762                                  Face Of The Earth
# 5823                        Everybody Loves The Sunshine
# 5822                             I Got You (I Feel Good)
# 5821                                            Sir Duke
# 5820   Night Fever - 2007 Remastered Version Saturday...
# 15763                                What's Left For Me?
# 5814                                  Give It To Me Baby
# 5813               Boogie Wonderland (with The Emotions)
#
#                            all_artists  popularity  danceability  energy  key  \
# 15534                        JP Cooper           0         0.623   0.656    0
# 15761                  Days Of The New           0         0.595   0.829   11
# 15762                  Days Of The New           0         0.639   0.674    6
# 5823                Roy Ayers Ubiquity           0         0.520   0.571   11
# 5822   James Brown & The Famous Flames           0         0.599   0.547    7
# 5821                     Stevie Wonder           0         0.587   0.566    6
# 5820                          Bee Gees           0         0.729   0.794    1
# 15763                  Days Of The New           0         0.561   0.629    1
# 5814                        Rick James           0         0.703   0.728   11
# 5813                      The Emotions           0         0.805   0.833    2
#
#        loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 15534    -5.608     0        0.0561          0.000000    0.0855    0.366
# 15761    -8.347     1        0.0406          0.000062    0.1320    0.592
# 15762    -8.629     1        0.2530          0.000397    0.2190    0.219
# 5823    -10.326     0        0.1680          0.000005    0.1700    0.701
# 5822     -8.102     1        0.2800          0.000000    0.1060    0.688
# 5821     -9.702     1        0.1780          0.000000    0.1070    0.950
# 5820     -7.208     0        0.0245          0.001250    0.0897    0.896
# 15763    -7.820     0        0.0150          0.000028    0.2000    0.164
# 5814     -8.698     1        0.1120          0.000057    0.1790    0.965
# 5813     -9.644     0        0.0985          0.021200    0.0205    0.968
#
#          tempo  time_signature release_year  duration
# 15534   95.878               4         2016       220
# 15761  135.456               4         1997       255
# 15762  120.442               1         1997       317
# 5823   161.051               3         1976       240
# 5822    70.095               5         2002       169
# 5821   106.780               4         2002       232
# 5820   109.123               4         1978       213
# 15763  134.503               3         1997       326
# 5814   119.538               4         1981       248
# 5813   131.805               4         1998       288

# %%
# 10 most popular songs in the dataset
most_popular = least_popular.tail(10)
most_popular
# Out:
#                            id  \
# 4326   3uUuGVFu1V7jTQL60S1r8z
# 4285   6Uj1ctrBOjOas8xZXGqKk4
# 25428  4ZtFanR9U6ndgddUvNcjcG
# 4298   6zSpb8dQRaw0M1dK8PBwQz
# 4359   20on25jryn53hWghthWWW3
# 4337   0gplL1WMoJ6iYaPgMCL0gX
# 5416   27NovPIUIRrOZoCHxABJwK
# 4274   5HCyWlXZPP0y6Gqq8TgA20
# 4356   1r9xUipOqoNwggBpENDsvJ
# 4362   4fouWK6XVHhzl78KzQ1UjL
#
#                                                    title        all_artists  \
# 4326                                   Where Are You Now        Calum Scott
# 4285                                               Woman           Doja Cat
# 25428                                           good 4 u     Olivia Rodrigo
# 4298                             Cold Heart - PNAU Remix               PNAU
# 4359                                         Do It To It            Cherish
# 4337                                          Easy On Me              Adele
# 5416                   INDUSTRY BABY (feat. Jack Harlow)        Jack Harlow
# 4274                           STAY (with Justin Bieber)      Justin Bieber
# 4356   Enemy (with JID) - from the series Arcane Leag...  League of Legends
# 4362                                             abcdefu              GAYLE
#
#        popularity  danceability  energy  key  loudness  mode  acousticness  \
# 4326           94         0.671   0.636    6    -8.117     0        0.5150
# 4285           95         0.824   0.764    5    -4.175     0        0.0888
# 25428          95         0.563   0.664    9    -5.044     1        0.3350
# 4298           96         0.796   0.798    1    -6.312     1        0.0340
# 4359           96         0.854   0.806   11    -8.262     0        0.0209
# 4337           96         0.604   0.366    5    -7.519     1        0.5780
# 5416           96         0.736   0.704    3    -7.409     0        0.0203
# 4274           97         0.591   0.764    1    -5.484     1        0.0383
# 4356           98         0.728   0.783   11    -4.424     0        0.2370
# 4362          100         0.695   0.540    4    -5.692     1        0.2990
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 4326           0.000411    0.1720    0.262  120.966               4
# 4285           0.002940    0.1170    0.881  107.998               4
# 25428          0.000000    0.0849    0.688  166.928               4
# 4298           0.000042    0.0952    0.942  116.032               4
# 4359           0.054200    0.0703    0.637  124.927               4
# 4337           0.000000    0.1330    0.130  141.981               4
# 5416           0.000000    0.0501    0.894  149.995               4
# 4274           0.000000    0.1030    0.478  169.928               4
# 4356           0.000000    0.4340    0.555   77.011               4
# 4362           0.000000    0.3670    0.415  121.932               4
#
#       release_year  duration
# 4326          2021       148
# 4285          2021       173
# 25428         2021       178
# 4298          2021       203
# 4359          2021       158
# 4337          2021       225
# 5416          2021       212
# 4274          2021       142
# 4356          2021       173
# 4362          2021       169

# %%
#How many unique artists?
df.all_artists.nunique()
# Out:
# 13560

# %%
#Top 10 artists who make for the most songs in the dataset
df.all_artists.value_counts()[:10]
# Out:
# Arctic Monkeys           113
# Johnny Cash               62
# Taylor Swift              61
# The Strokes               49
# Kanye West                46
# Red Hot Chili Peppers     45
# blink-182                 45
# Cage The Elephant         45
# The Rolling Stones        45
# Eminem                    43
# Name: all_artists, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'title', 'all_artists', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'release_year',
#        'duration'],
#       dtype='object')

# %%
#Map the correlation of features
corr_df = df[['popularity', 'release_year',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
       'duration']].corr()

plt.figure(figsize = (15,8))
heatmap = sns.heatmap(corr_df,
                     annot = True,
                      vmin= -1,
                      vmax = 1,
                     cmap = 'winter',
                     linecolor='Black')
heatmap.set_title('Correlation Heatmap between features');

# %%
#Top 10 artists in terms of average energy compared to their average accousticness (really negative correlation between these features)
df[['all_artists','energy','acousticness']].groupby('all_artists').mean().sort_values(by='energy', ascending=False)[:10]
# Out:
#                             energy  acousticness
# all_artists
# DJ Hush                      0.999      0.000073
# Captain Jack                 0.999      0.072600
# Timo Revna                   0.999      0.001310
# Agneton                      0.999      0.012900
# Thinktank                    0.999      0.000238
# Blushing Ocean Wave Sounds   0.999      0.365000
# Jasad                        0.999      0.000001
# Paysage D'Hiver              0.999      0.002070
# DJ Rentgen                   0.999      0.023300
# Alignment                    0.998      0.000564

# %%
df.columns
# Out:
# Index(['id', 'title', 'all_artists', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'release_year',
#        'duration'],
#       dtype='object')

# %%
#How characteristics of songs change over the years
avgs_by_year = df[['danceability', 'energy', 'loudness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'release_year',
       'duration']].groupby('release_year').mean().sort_values(by='release_year').reset_index()
avgs_by_year.head()
# Out:
#   release_year  danceability  energy  loudness  acousticness  \
# 0         1900         0.582  0.5890    -8.647        0.0574
# 1         1921         0.757  0.5040    -8.157        0.9260
# 2         1923         0.614  0.0423   -12.033        0.9960
# 3         1926         0.498  0.2580   -12.622        0.9640
# 4         1927         0.541  0.0946   -19.886        0.8820
#
#    instrumentalness  liveness  valence    tempo  duration
# 0           0.00326    0.3130    0.466  131.979     288.0
# 1           0.92800    0.2610    0.944   94.325     159.0
# 2           0.00293    0.1830    0.211   89.822     177.0
# 3           0.00486    0.1240    0.687   82.476     188.0
# 4           0.00000    0.0979    0.470  166.893     193.0

# %%
#Plot these changes
plt.figure(figsize=(14,8))
plt.title("Song Trends Over Time", fontsize=15)
lines = ['danceability', 'energy', 'acousticness', 'instrumentalness',
       'liveness', 'valence']
for line in lines:
    ax = sns.lineplot(x='release_year', y=line, data= avgs_by_year)
plt.legend(lines);

# %%
#Plot these changes only for duration
plt.figure(figsize=(14,8))
plt.title("Song Trends Over Time", fontsize=15)
lines = ['duration']
for line in lines:
    ax = sns.lineplot(x='release_year', y=line, data= avgs_by_year)
plt.legend(lines);

# %%
df.columns
# Out:
# Index(['id', 'title', 'all_artists', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'release_year',
#        'duration'],
#       dtype='object')

# %% [markdown]
# ---
# https://www.youtube.com/watch?v=v_sPnwoT_iA&list=TLPQMTgwMTIwMjLOQNHMg9wb3w&index=6

# %%
#Danceability
ax1.set_xlabel('Danceability')
ax1.set_ylabel('Count')
ax1.set_title('Song danceability distribution')
df.hist(column = ['danceability'], bins = 40);

# %%
#Acousticness
ax1.set_xlabel('Acousticnesss')
ax1.set_ylabel('Count')
ax1.set_title('Song acousticness')
df.hist(column = ['acousticness'], bins = 40);

# %%
#Valence
ax1.set_xlabel('Valence')
ax1.set_ylabel('Count')
ax1.set_title('Song valence')
df.hist(column = ['valence'], bins = 40);

# %%
#Instrumentalness
ax1.set_xlabel('Instrumentalness')
ax1.set_ylabel('Count')
ax1.set_title('Song instrumentalness')
df.hist(column = ['instrumentalness'], bins = 40);
